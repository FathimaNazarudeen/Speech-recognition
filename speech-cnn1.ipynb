# %%
# Import libraries 
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from matplotlib.pyplot import specgram
import pandas as pd
import glob 
from sklearn.metrics import confusion_matrix
import IPython.display as ipd  # To play sound in the notebook
import os
import sys
import warnings
# ignore warnings 
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
Emotions= pd.read_csv('/kaggle/input/emotion/emotion (1).csv')
Emotions.head()
# Out:
#             0           1         2          3          4         5  \
# 0 -258.990326  132.193741  5.314349  21.521330 -24.357752 -2.237025
# 1 -258.667152  132.047682  5.236842  21.529129 -24.335813 -2.170860
# 2 -301.181824  128.659897  4.380285   9.940308 -23.697367 -7.601327
# 3 -274.135437  142.405472 -2.322214  21.200804 -27.737436 -1.496183
# 4 -274.135437  142.405472 -2.322214  21.200804 -27.737436 -1.496183
#
#            6          7          8         9  ...        31        32  \
# 0 -24.086287  -9.530801 -20.967497 -4.285268  ... -0.953883  1.146237
# 1 -24.135509  -9.465332 -20.959675 -4.215839  ... -0.906946  1.140402
# 2 -25.921268 -13.189119 -19.924520 -0.300373  ...  3.321182  3.191138
# 3 -26.762552 -10.112954 -21.643480 -3.658734  ... -1.149690  1.346368
# 4 -26.762552 -10.112954 -21.643480 -3.658734  ... -1.149690  1.346368
#
#          33        34        35        36        37        38        39  \
# 0  1.829600  2.893938  1.310414  1.626812  2.758013  4.257873  3.918041
# 1  1.826270  2.867984  1.350153  1.576485  2.766849  4.228887  3.915566
# 2  3.419615  3.112536  1.654553  3.749860  5.546700  4.269989  1.401541
# 3  2.298612  3.353943  1.820001  2.129130  2.610373  4.910376  4.944275
# 4  2.298612  3.353943  1.820001  2.129130  2.610373  4.910376  4.944275
#
#        labels
# 0  male_happy
# 1  male_happy
# 2  male_happy
# 3  male_happy
# 4  male_happy
#
# [5 rows x 41 columns]

# %%
X = Emotions.drop('labels',axis = 1)
Y = Emotions['labels']

# %%
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split

# %%
# since it is a multiclass classifier, i will perform onehotencoding
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size = 0.2,shuffle = True)

x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((48648, 40), (48648, 14), (12162, 40), (12162, 14))

# %%
# scaling our data with sklearn's Standard scaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((48648, 40), (48648, 14), (12162, 40), (12162, 14))

# %% [markdown]
# CNN

# %%
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv1D,Dense,AveragePooling1D,Dropout,add,BatchNormalization,LSTM,Flatten,MaxPooling1D,GRU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.activations import relu, softmax
from keras.activations import relu, softmax
from sklearn.metrics import confusion_matrix,classification_report

# %%
x_traincnn =np.expand_dims(x_train, axis=2)
x_testcnn= np.expand_dims(x_test, axis=2)
x_traincnn.shape, y_train.shape, x_testcnn.shape, y_test.shape
# Out:
# ((48648, 40, 1), (48648, 14), (12162, 40, 1), (12162, 14))

# %%
my_model=Sequential()
my_model.add(Conv1D(256, kernel_size=7, strides=1, padding='same', activation='relu', input_shape=(x_train.shape[1], 1)))
my_model.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
my_model.add(BatchNormalization())

my_model.add(Conv1D(128, kernel_size=7, strides=1, padding='same', activation='relu'))
my_model.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
my_model.add(BatchNormalization())

my_model.add(Conv1D(128, kernel_size=7, strides=1, padding='same', activation='relu'))
my_model.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
my_model.add(BatchNormalization())


my_model.add(Conv1D(64, kernel_size=7, strides=1, padding='same', activation='relu'))
my_model.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
my_model.add(BatchNormalization())
my_model.add(Dropout(0.5))
        
my_model.add(Flatten())
my_model.add(Dense(units=32, activation='relu'))
my_model.add(Dropout(0.5))

my_model.add(Dense(units=14, activation='softmax'))
my_model.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

my_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 40, 256)           2048
#
#  max_pooling1d (MaxPooling1D  (None, 20, 256)          0
#  )
#
#  batch_normalization (BatchN  (None, 20, 256)          1024
#  ormalization)
#
#  conv1d_1 (Conv1D)           (None, 20, 128)           229504
#
#  max_pooling1d_1 (MaxPooling  (None, 10, 128)          0
#  1D)
#
#  batch_normalization_1 (Batc  (None, 10, 128)          512
#  hNormalization)
#
#  conv1d_2 (Conv1D)           (None, 10, 128)           114816
#
#  max_pooling1d_2 (MaxPooling  (None, 5, 128)           0
#  1D)
#
#  batch_normalization_2 (Batc  (None, 5, 128)           512
#  hNormalization)
#
#  conv1d_3 (Conv1D)           (None, 5, 64)             57408
#
#  max_pooling1d_3 (MaxPooling  (None, 3, 64)            0
#  1D)
#
#  batch_normalization_3 (Batc  (None, 3, 64)            256
#  hNormalization)
#
#  dropout (Dropout)           (None, 3, 64)             0
#
#  flatten (Flatten)           (None, 192)               0
#
#  dense (Dense)               (None, 32)                6176
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 14)                462
#
# =================================================================
# Total params: 412,718
# Trainable params: 411,566
# Non-trainable params: 1,152
# _________________________________________________________________

# %%
history = my_model.fit(x_traincnn, y_train, batch_size=32, epochs=100, validation_data=(x_testcnn, y_test))
# Out:
# Epoch 1/100
# 1521/1521 [==============================] - 19s 9ms/step - loss: 2.0059 - accuracy: 0.3217 - val_loss: 1.4232 - val_accuracy: 0.4862
# Epoch 2/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 1.5061 - accuracy: 0.4531 - val_loss: 1.2247 - val_accuracy: 0.5497
# Epoch 3/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 1.3541 - accuracy: 0.4966 - val_loss: 1.1445 - val_accuracy: 0.5682
# Epoch 4/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 1.2668 - accuracy: 0.5247 - val_loss: 1.0643 - val_accuracy: 0.5920
# Epoch 5/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 1.1863 - accuracy: 0.5547 - val_loss: 1.0113 - val_accuracy: 0.6150
# Epoch 6/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 1.1276 - accuracy: 0.5768 - val_loss: 0.9897 - val_accuracy: 0.6159
# Epoch 7/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 1.0747 - accuracy: 0.5981 - val_loss: 0.9263 - val_accuracy: 0.6427
# Epoch 8/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 1.0142 - accuracy: 0.6191 - val_loss: 0.8743 - val_accuracy: 0.6705
# Epoch 9/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.9758 - accuracy: 0.6381 - val_loss: 0.8698 - val_accuracy: 0.6712
# Epoch 10/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.9266 - accuracy: 0.6558 - val_loss: 0.8305 - val_accuracy: 0.6914
# Epoch 11/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.8893 - accuracy: 0.6668 - val_loss: 0.8001 - val_accuracy: 0.7055
# Epoch 12/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.8586 - accuracy: 0.6825 - val_loss: 0.7798 - val_accuracy: 0.7087
# Epoch 13/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.8124 - accuracy: 0.7023 - val_loss: 0.7519 - val_accuracy: 0.7272
# Epoch 14/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.7918 - accuracy: 0.7099 - val_loss: 0.7509 - val_accuracy: 0.7331
# Epoch 15/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.7510 - accuracy: 0.7282 - val_loss: 0.7249 - val_accuracy: 0.7396
# Epoch 16/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.7231 - accuracy: 0.7394 - val_loss: 0.7194 - val_accuracy: 0.7445
# Epoch 17/100
# 1521/1521 [==============================] - 15s 10ms/step - loss: 0.6971 - accuracy: 0.7483 - val_loss: 0.7179 - val_accuracy: 0.7475
# Epoch 18/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.6743 - accuracy: 0.7571 - val_loss: 0.6982 - val_accuracy: 0.7534
# Epoch 19/100
# 1521/1521 [==============================] - 14s 9ms/step - loss: 0.6508 - accuracy: 0.7648 - val_loss: 0.6956 - val_accuracy: 0.7632
# Epoch 20/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.6325 - accuracy: 0.7744 - val_loss: 0.6977 - val_accuracy: 0.7633
# Epoch 21/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.6093 - accuracy: 0.7837 - val_loss: 0.6555 - val_accuracy: 0.7815
# Epoch 22/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.5866 - accuracy: 0.7923 - val_loss: 0.6718 - val_accuracy: 0.7826
# Epoch 23/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.5664 - accuracy: 0.8002 - val_loss: 0.6605 - val_accuracy: 0.7857
# Epoch 24/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.5561 - accuracy: 0.8042 - val_loss: 0.6675 - val_accuracy: 0.7856
# Epoch 25/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.5435 - accuracy: 0.8105 - val_loss: 0.6584 - val_accuracy: 0.7929
# Epoch 26/100
# 1521/1521 [==============================] - 14s 9ms/step - loss: 0.5281 - accuracy: 0.8144 - val_loss: 0.6306 - val_accuracy: 0.7990
# Epoch 27/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.5110 - accuracy: 0.8226 - val_loss: 0.6539 - val_accuracy: 0.7910
# Epoch 28/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.4953 - accuracy: 0.8264 - val_loss: 0.6301 - val_accuracy: 0.7995
# Epoch 29/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.4875 - accuracy: 0.8294 - val_loss: 0.6397 - val_accuracy: 0.8060
# Epoch 30/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.4716 - accuracy: 0.8374 - val_loss: 0.6508 - val_accuracy: 0.8000
# Epoch 31/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.4668 - accuracy: 0.8408 - val_loss: 0.6505 - val_accuracy: 0.8039
# Epoch 32/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.4471 - accuracy: 0.8436 - val_loss: 0.6625 - val_accuracy: 0.8073
# Epoch 33/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.4407 - accuracy: 0.8462 - val_loss: 0.6608 - val_accuracy: 0.8105
# Epoch 34/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.4271 - accuracy: 0.8538 - val_loss: 0.6471 - val_accuracy: 0.8106
# Epoch 35/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.4219 - accuracy: 0.8562 - val_loss: 0.6747 - val_accuracy: 0.8061
# Epoch 36/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.4053 - accuracy: 0.8601 - val_loss: 0.6571 - val_accuracy: 0.8103
# Epoch 37/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.4005 - accuracy: 0.8623 - val_loss: 0.6682 - val_accuracy: 0.8149
# Epoch 38/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.3887 - accuracy: 0.8646 - val_loss: 0.7091 - val_accuracy: 0.8122
# Epoch 39/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.3930 - accuracy: 0.8667 - val_loss: 0.6604 - val_accuracy: 0.8185
# Epoch 40/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.3725 - accuracy: 0.8725 - val_loss: 0.6682 - val_accuracy: 0.8203
# Epoch 41/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.3689 - accuracy: 0.8736 - val_loss: 0.6620 - val_accuracy: 0.8200
# Epoch 42/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.3614 - accuracy: 0.8776 - val_loss: 0.6668 - val_accuracy: 0.8215
# Epoch 43/100
# 1521/1521 [==============================] - 14s 9ms/step - loss: 0.3559 - accuracy: 0.8785 - val_loss: 0.6671 - val_accuracy: 0.8271
# Epoch 44/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.3459 - accuracy: 0.8822 - val_loss: 0.6800 - val_accuracy: 0.8265
# Epoch 45/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.3478 - accuracy: 0.8834 - val_loss: 0.6740 - val_accuracy: 0.8297
# Epoch 46/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.3433 - accuracy: 0.8846 - val_loss: 0.6685 - val_accuracy: 0.8222
# Epoch 47/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.3281 - accuracy: 0.8882 - val_loss: 0.7065 - val_accuracy: 0.8283
# Epoch 48/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.3279 - accuracy: 0.8893 - val_loss: 0.6833 - val_accuracy: 0.8240
# Epoch 49/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.3258 - accuracy: 0.8897 - val_loss: 0.6865 - val_accuracy: 0.8297
# Epoch 50/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.3091 - accuracy: 0.8955 - val_loss: 0.7105 - val_accuracy: 0.8254
# Epoch 51/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.3167 - accuracy: 0.8943 - val_loss: 0.7099 - val_accuracy: 0.8297
# Epoch 52/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.3087 - accuracy: 0.8959 - val_loss: 0.6848 - val_accuracy: 0.8323
# Epoch 53/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.2995 - accuracy: 0.9006 - val_loss: 0.7172 - val_accuracy: 0.8308
# Epoch 54/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.2946 - accuracy: 0.9015 - val_loss: 0.7220 - val_accuracy: 0.8321
# Epoch 55/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.2839 - accuracy: 0.9046 - val_loss: 0.7397 - val_accuracy: 0.8334
# Epoch 56/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.2911 - accuracy: 0.9017 - val_loss: 0.7341 - val_accuracy: 0.8317
# Epoch 57/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.2825 - accuracy: 0.9068 - val_loss: 0.7480 - val_accuracy: 0.8333
# Epoch 58/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.2819 - accuracy: 0.9068 - val_loss: 0.7444 - val_accuracy: 0.8309
# Epoch 59/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.2777 - accuracy: 0.9093 - val_loss: 0.7336 - val_accuracy: 0.8315
# Epoch 60/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.2678 - accuracy: 0.9115 - val_loss: 0.7475 - val_accuracy: 0.8280
# Epoch 61/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.2653 - accuracy: 0.9113 - val_loss: 0.7614 - val_accuracy: 0.8365
# Epoch 62/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.2620 - accuracy: 0.9148 - val_loss: 0.7533 - val_accuracy: 0.8285
# Epoch 63/100
# 1521/1521 [==============================] - 14s 9ms/step - loss: 0.2590 - accuracy: 0.9130 - val_loss: 0.7804 - val_accuracy: 0.8352
# Epoch 64/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.2624 - accuracy: 0.9149 - val_loss: 0.7591 - val_accuracy: 0.8346
# Epoch 65/100
# 1521/1521 [==============================] - 14s 9ms/step - loss: 0.2511 - accuracy: 0.9175 - val_loss: 0.7607 - val_accuracy: 0.8339
# Epoch 66/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.2517 - accuracy: 0.9169 - val_loss: 0.7872 - val_accuracy: 0.8366
# Epoch 67/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.2536 - accuracy: 0.9163 - val_loss: 0.7894 - val_accuracy: 0.8384
# Epoch 68/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.2476 - accuracy: 0.9188 - val_loss: 0.7902 - val_accuracy: 0.8363
# Epoch 69/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.2422 - accuracy: 0.9209 - val_loss: 0.7823 - val_accuracy: 0.8378
# Epoch 70/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.2373 - accuracy: 0.9200 - val_loss: 0.8065 - val_accuracy: 0.8392
# Epoch 71/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.2364 - accuracy: 0.9216 - val_loss: 0.8134 - val_accuracy: 0.8296
# Epoch 72/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.2364 - accuracy: 0.9220 - val_loss: 0.7968 - val_accuracy: 0.8370
# Epoch 73/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.2294 - accuracy: 0.9245 - val_loss: 0.7936 - val_accuracy: 0.8395
# Epoch 74/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.2338 - accuracy: 0.9238 - val_loss: 0.8227 - val_accuracy: 0.8412
# Epoch 75/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.2301 - accuracy: 0.9260 - val_loss: 0.8117 - val_accuracy: 0.8365
# Epoch 76/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.2269 - accuracy: 0.9261 - val_loss: 0.8327 - val_accuracy: 0.8314
# Epoch 77/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.2242 - accuracy: 0.9269 - val_loss: 0.8454 - val_accuracy: 0.8346
# Epoch 78/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.2214 - accuracy: 0.9280 - val_loss: 0.7991 - val_accuracy: 0.8337
# Epoch 79/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.2162 - accuracy: 0.9302 - val_loss: 0.8543 - val_accuracy: 0.8408
# Epoch 80/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.2121 - accuracy: 0.9295 - val_loss: 0.8313 - val_accuracy: 0.8345
# Epoch 81/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.2240 - accuracy: 0.9276 - val_loss: 0.8440 - val_accuracy: 0.8393
# Epoch 82/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.2092 - accuracy: 0.9313 - val_loss: 0.8334 - val_accuracy: 0.8404
# Epoch 83/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.2085 - accuracy: 0.9320 - val_loss: 0.8558 - val_accuracy: 0.8372
# Epoch 84/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.2068 - accuracy: 0.9316 - val_loss: 0.9051 - val_accuracy: 0.8360
# Epoch 85/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.2056 - accuracy: 0.9317 - val_loss: 0.8705 - val_accuracy: 0.8411
# Epoch 86/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.2131 - accuracy: 0.9306 - val_loss: 0.8615 - val_accuracy: 0.8385
# Epoch 87/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.2019 - accuracy: 0.9349 - val_loss: 0.8353 - val_accuracy: 0.8345
# Epoch 88/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.1958 - accuracy: 0.9369 - val_loss: 0.8736 - val_accuracy: 0.8373
# Epoch 89/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.1993 - accuracy: 0.9351 - val_loss: 0.8364 - val_accuracy: 0.8393
# Epoch 90/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.1927 - accuracy: 0.9362 - val_loss: 0.8646 - val_accuracy: 0.8360
# Epoch 91/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.1979 - accuracy: 0.9357 - val_loss: 0.8664 - val_accuracy: 0.8397
# Epoch 92/100
# 1521/1521 [==============================] - 14s 9ms/step - loss: 0.1964 - accuracy: 0.9366 - val_loss: 0.9092 - val_accuracy: 0.8379
# Epoch 93/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.1945 - accuracy: 0.9365 - val_loss: 0.8949 - val_accuracy: 0.8390
# Epoch 94/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.1949 - accuracy: 0.9374 - val_loss: 0.9085 - val_accuracy: 0.8379
# Epoch 95/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.1866 - accuracy: 0.9401 - val_loss: 0.9339 - val_accuracy: 0.8412
# Epoch 96/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.1866 - accuracy: 0.9395 - val_loss: 0.9611 - val_accuracy: 0.8379
# Epoch 97/100
# 1521/1521 [==============================] - 13s 9ms/step - loss: 0.1867 - accuracy: 0.9386 - val_loss: 0.9492 - val_accuracy: 0.8360
# Epoch 98/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.1969 - accuracy: 0.9372 - val_loss: 0.8995 - val_accuracy: 0.8407
# Epoch 99/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.1822 - accuracy: 0.9426 - val_loss: 0.8961 - val_accuracy: 0.8416
# Epoch 100/100
# 1521/1521 [==============================] - 13s 8ms/step - loss: 0.1790 - accuracy: 0.9421 - val_loss: 0.9507 - val_accuracy: 0.8358

# %%
print("Accuracy of our model on test data : " , round(my_model.evaluate(x_testcnn,y_test)[1],2)*100 , "%")
# Out:
# 381/381 [==============================] - 1s 3ms/step - loss: 0.9507 - accuracy: 0.8358
# Accuracy of our model on test data :  84.0 %

# %%
model_name = 'emotion_model.h5'
save_dir = os.path.join(os.getcwd(), 'saved_models')
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)   # adds file in folder
my_model.save(model_path)
print('Save model and weights at %s' % model_path)
model_json = my_model.to_json()
with open('model_json.json', 'w') as json_file:
    json_file.write(model_json)
# Out:
# Save model and weights at /kaggle/working/saved_models/emotion_model.h5

# %%
epochs = [i for i in range(100)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()

# %% [markdown]
# Confusion Matrix

# %%
# predicting on test data.
pred_test = my_model.predict(x_testcnn)
y_pred = encoder.inverse_transform(pred_test)
y_test = encoder.inverse_transform(y_test)
# Out:
# 381/381 [==============================] - 1s 3ms/step

# %%
df = pd.DataFrame(columns=['PredictedLabels', 'ActualLabels'])
df['PredictedLabels'] = y_pred.flatten()
df['ActualLabels'] = y_test.flatten()

# %%
df
# Out:
#        PredictedLabels     ActualLabels
# 0       female_disgust   female_disgust
# 1             male_sad         male_sad
# 2          female_fear      female_fear
# 3         female_angry     female_angry
# 4          female_fear      female_fear
# ...                ...              ...
# 12157     female_angry     female_angry
# 12158   female_neutral   female_neutral
# 12159  female_surprise  female_surprise
# 12160       male_happy        male_fear
# 12161     female_angry     female_angry
#
# [12162 rows x 2 columns]

# %%
df.to_csv('Predictions.csv', index = False)

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (8,5))
cm = pd.DataFrame(cm , index = [i for i in encoder.categories_] , columns = [i for i in encoder.categories_])
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#    female_angry       0.92      0.91      0.91      1112
#  female_disgust       0.83      0.86      0.84      1077
#     female_fear       0.88      0.86      0.87      1067
#    female_happy       0.88      0.89      0.88      1090
#  female_neutral       0.89      0.86      0.88      1095
#      female_sad       0.85      0.86      0.85      1096
# female_surprise       0.98      0.98      0.98       456
#      male_angry       0.89      0.84      0.86       841
#    male_disgust       0.72      0.73      0.73       864
#       male_fear       0.78      0.75      0.77       858
#      male_happy       0.67      0.79      0.73       824
#    male_neutral       0.82      0.75      0.79       825
#        male_sad       0.76      0.78      0.77       811
#   male_surprise       0.90      0.89      0.89       146
#
#        accuracy                           0.84     12162
#       macro avg       0.84      0.84      0.84     12162
#    weighted avg       0.84      0.84      0.84     12162

# %%
import keras

# %% [markdown]
# # Emotion accuracy

# %%
modidf = pd.read_csv("Predictions.csv")
modidf['actualvalues'] = modidf.ActualLabels.replace({'female_angry':'angry'
                                       , 'female_disgust':'disgust'
                                       , 'female_fear':'fear'
                                       , 'female_happy':'happy'
                                       , 'female_sad':'sad'
                                       , 'female_surprise':'surprise'
                                       , 'female_neutral':'neutral'
                                       , 'male_angry':'angry'
                                       , 'male_fear':'fear'
                                       , 'male_happy':'happy'
                                       , 'male_sad':'sad'
                                       , 'male_surprise':'surprise'
                                       , 'male_neutral':'neutral'
                                       , 'male_disgust':'disgust'
                                      })

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import seaborn as sns

# %%
modidf['predictedvalues'] = modidf.PredictedLabels.replace({'female_angry':'angry'
                                       , 'female_disgust':'disgust'
                                       , 'female_fear':'fear'
                                       , 'female_happy':'happy'
                                       , 'female_sad':'sad'
                                       , 'female_surprise':'surprise'
                                       , 'female_neutral':'neutral'
                                       , 'male_angry':'angry'
                                       , 'male_fear':'fear'
                                       , 'male_happy':'happy'
                                       , 'male_sad':'sad'
                                       , 'male_surprise':'surprise'
                                       , 'male_neutral':'neutral'
                                       , 'male_disgust':'disgust'
                                      })

classes = modidf.actualvalues.unique()  
classes.sort() 
# Confusion matrix 
c = confusion_matrix(modidf.actualvalues, modidf.predictedvalues)
print(accuracy_score(modidf.actualvalues, modidf.predictedvalues))
# Out:
# 0.8428712382831771

# %%
cm = confusion_matrix(modidf.actualvalues, modidf.predictedvalues)
plt.figure(figsize = (8,5))
x= pd.DataFrame(cm,  columns=(classes), index=(classes))
sns.heatmap(x, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %% [markdown]
# # Classification report

# %%
classes = modidf.actualvalues.unique()
classes.sort()    
print(classification_report(modidf.actualvalues, modidf.predictedvalues, target_names=classes))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.92      0.89      0.90      1953
#      disgust       0.80      0.82      0.81      1941
#         fear       0.84      0.82      0.83      1925
#        happy       0.79      0.85      0.82      1914
#      neutral       0.87      0.82      0.84      1920
#          sad       0.82      0.83      0.83      1907
#     surprise       0.96      0.96      0.96       602
#
#     accuracy                           0.84     12162
#    macro avg       0.86      0.85      0.85     12162
# weighted avg       0.84      0.84      0.84     12162
